# %% [markdown]
# # Indication Mapping
#
# This notebook demonstrates local helpers used to construct drug-disease indication maps from normalized source tables.

# %%
import pandas as pd
import ehrapy_drug_screening as eds

# %%
product = pd.DataFrame({"prodcode": [10], "bnfcode": ["0101010A0"]})
eds.tl.build_bnfcode_prodcode_map(product)

# %%
rxcui_prodcode = pd.DataFrame({"rxcui": ["123"], "prodcode": [10]})
rxcui_medcode = pd.DataFrame({"rxcui": ["123"], "medcode": ["m1"]})
eds.tl.build_prodcode_medcode_map(rxcui_prodcode, rxcui_medcode)
