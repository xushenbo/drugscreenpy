# %% [markdown]
# # Data Requirements and Schema
#
# This notebook introduces the minimum table structure used by the drug-screening workflow.

# %%
import pandas as pd

# %% [markdown]
# The workflow expects patient identifiers, prescription dates, drug labels, follow-up dates, and disease-event dates.

# %%
therapy = pd.DataFrame(
    {
        "patid": [1, 2, 3],
        "eventdate": ["2020-01-10", "2020-01-10", "2020-01-10"],
        "drugsubstance": ["drug_a", "drug_a", "drug_a"],
        "duration": [5, 5, 5],
    }
)
patients = pd.DataFrame(
    {
        "patid": [1, 2, 3],
        "dob": ["1970-01-01"] * 3,
        "frd": ["2019-01-01"] * 3,
        "tod": ["2021-01-01"] * 3,
        "lcd": ["2021-01-01"] * 3,
        "deathdate": ["2021-01-01"] * 3,
    }
)
events = pd.DataFrame(
    {
        "patid": [1, 2, 3],
        "disease": ["disease_x"] * 3,
        "disease_eventdate": pd.to_datetime(["2020-01-12", "2020-01-06", "2020-01-13"]),
    }
)
therapy
